# %% [markdown]
# <a href="https://colab.research.google.com/github/veronicaluzzi/Data-Science-Cohort-20/blob/main/Exercises/Module_1/1e_Data_Science_Problem_Definition_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Problem Definition

# %% [markdown]
# For each item develop a well-worded data science problem statement.  Your answer should include what type of data science problem this is ( supervised vs unsupervised ) and then whether it is a classification, regression, or clustering problem.  If it is a supervised problem, you should state what the target of the prediction is.

# %% [markdown]
# 1. Zillow wants you to predict real estate sales prices. They have a large
# database of 12 years of home features accompanied by the corresponding
# sales prices.
# ________________

# %% [markdown]
# **Statement**:
#
# ( Analyze historical property features and listing data to predict real estate sales price.  This is a **supervised** learning because I have the *input* (12 years of home features information), and the *output* or sale value.  It is a **regression** problem since the goal is to predict a continuous numerical value (sale price) rather than a discrete category. The **target variable** for the prediction is the home's final sale price. The **target data type is numerical, continuous**.
# )

# %% [markdown]
# ---
#
# 2. Amazon wants you to develop a code that upsells (add additional items to the customer’s order) based on what items have been viewed and bought by that
# customer over the past 2 years.
# ________________________

# %% [markdown]
# **Statement**:
#
# ( Based on a customer's 2-year history of viewed and purchased items, develop an algorithm to recommend additional high-value or complementary items to increase the total order value (upselling).  My logic:
# - Based on this data we need to predict what items to add to the list of offerings to get the client to buy more or upsell.
# - This is a **Supervised** data science problem because I know the input, and the output
# - Input: 2 years of purchasing data
# - Output: items added to the list of offerings
# - Data science problem statement: Identify what other listings to add to the offerings based on 2 years of purchasing data.
# - Target: what items to add to the list (items = nominal).  In this case the target is categorical, nominal
# - ML moded: supervised, categorical, nominal
#  )

# %% [markdown]
# ---
#
# 3. MGM wants to know what features of a movie seem to increase the movie’s
# box office income. They have a large database of previously released movies
# accompanied by the resulting box office revenue.
# __________________

# %% [markdown]
# **Statement**:
#
# ( Analyze historical movie data to identify which specific features (such as genre, lead actors, budget, or release season) have the strongest positive correlation with box office revenue.  My assumptions:
#
#
# - MGM has historical data relating movie’s features with box office income.
# - Data Science problem statement: analyze MGM historical data to predict what movie feature will increase box office income.
# - Input: historical movie feature data relating to box office income
# - Output: what feature increases the box office income
# - ML model: supervised, categorical, nominal
#
#
#
#  )

# %% [markdown]
# ---
#
# 4. Spotify wants you to develop a method of predicting whether a customer is
# about to terminate their service BEFORE they terminate so that they can offer
# enticements to the customer to keep the service and not terminate (called
# ‘churn’)
# _________________

# %% [markdown]
# **Statement**:
#
# ( The objective of this project is to predict the likelihood of customer churn by identifying at-risk users before they cancel their subscriptions.
# The assumption is that there is data correlating customer canceling subscription.
# Based on that assumption, this is a **supervised learning task** because the model is trained on historical data where the outcome (whether a user stayed or left) is already known. Specifically, it is a **binary classification** problem because the target variable is a discrete, two-choice category: Churn vs. No Churn.)

# %% [markdown]
# ---
#
# 5. Comcast wants you to develop a chat bot (automated customer service) to
# take text input and respond with the appropriate help and/or service
# response.
# ________________

# %% [markdown]
# **Statement**:
#
# ( Develop a system to analyze incoming customer text queries and accurately categorize the intent to provide the most relevant service response or technical solution.  My assumptions:
#
#
#
# 1.  I have data to support the bot answers based on previously recorded customer conversations.
# 2.  There has been a large training set 'teaching' the bot what the correct answer is using a Natural Language processing.  The 'correct' answer has been trained.
#
# Based on these assumptions, this is a **supervised** model that uses a multiple **classification** to identify answers.
#
# )

# %% [markdown]
# \---
#
# 6. Instagram wants you to analyze images and output whether the image
# contains people, animals, scenery, or some other subject.
# ________________

# %% [markdown]
# Statement:
#
# { Develop a model to analyze the visual content of uploaded images and automatically assign a primary subject label, such as 'Person,' 'Animal,' or 'Scenery'.). My assumptions:
#
# 1. I have already pre-trained the model to be able to identify the different images and assign them a label.
# 2. There are multiple categories of images.
#
# This is a **supervised**, **multi-classification** problem.
