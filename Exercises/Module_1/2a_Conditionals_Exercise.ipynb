# %% [markdown]
# <a href="https://colab.research.google.com/github/veronicaluzzi/Data-Science-Cohort-20/blob/main/Exercises/Module_1/2a_Conditionals_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conditionals Exercises

# %% [markdown]
# 1. Print 'A is really BIG!' if a is greater than b.
#
# ```python
# a = 900
# b = 7
# ```

# %%
a = 900
b = 7
if (a>b):
  print('A is really BIG!')
# Out:
# A is really BIG!

# %% [markdown]
# 2. If a and b are equal print 'These things are the same'.  Otherwise, print 'These things are not the same'.
#
# ```python
# a = 2
# b = 4
# ```

# %%
a=2
b=4
if (a == b):
  print('These things are the same')
else:
  print('These things are not the same')
# Out:
# These things are not the same

# %% [markdown]
# 3. If a is greater than b AND b is greater than c, print your own silly sentence.
#
# ```python
# a = 9
# b = 5
# c = 2
# ```

# %%
a = 9
b = 5
c = 2
if ( a > b ) and ( b > c ):
  print ( 'all cows are red but mine')
# Out:
# all cows are red but mine

# %% [markdown]
# 4. If your favorite ice cream is in the list of flavors, print 'I am so happy!'
#
# ```python
# flavors = [
#   'chocolate',
#   'vanilla',
#   'strawberry',
#   'chocolate-chip',
#   "Ben and Jerry's Half-Baked",
# ]
# ```

# %%
flavors = [
  'chocolate',
  'vanilla',
  'strawberry',
  'chocolate-chip',
  "Ben and Jerry's Half-Baked",
]
print (flavors)
# Out:
# ['chocolate', 'vanilla', 'strawberry', 'chocolate-chip', "Ben and Jerry's Half-Baked"]

# %%
if ( 'vanilla' in flavors ):
  print('I am so happy!')
# Out:
# I am so happy!

# %%
if ( 'rocky road' in flavors ):
  print('I am so happy!')

# %% [markdown]
# 5. Make a list called mypets with your pets (real or imaginary) as elements.
# - if mypets contains 'dog' and 'cat', print 'I am a dog person and a cat person'
# - else if mypets contains 'dog', print 'I am a dog person'
# - else if mypets contains 'cat', print 'I am a cat person'
# - otherwise, print 'I am not a cat person or a dog person'
#
# ```python
# mypets = [  ]
# ```

# %%
mypets = [
'dog',
'cat',
'turtle',
'chipmonk',
'bird'
]
print (mypets)
# Out:
# ['dog', 'cat', 'turtle', 'chipmonk', 'bird']

# %%
if ('dog' in mypets):
  print (mypets)
# Out:
# ['dog', 'cat', 'turtle', 'chipmonk', 'bird']

# %%
#this is not working but left here to learn how to do it
#if mypets contains 'dog' and 'cat', print 'I am a dog person and a cat person'
#else if mypets contains 'dog', print 'I am a dog person'
#else if mypets contains 'cat', print 'I am a cat person'
#otherwise, print 'I am not a cat person or a dog person
a = ('dog' in mypets)
b = ('cat' in mypets)
match ( a, b ):
  case (True, True):
    print('I am a dog person and a cat person')
  case (False, False):
    print('I am not a cat person or a dog person')
  case (True, False):
    print('I am a dog person')
  case ( False, True ):
    print("I am a cat person")
# Out:
# I am a dog person and a cat person

# %%
#if mypets contains 'dog' and 'cat', print 'I am a dog person and a cat person'
#else if mypets contains 'dog', print 'I am a dog person'
#else if mypets contains 'cat', print 'I am a cat person'
#otherwise, print 'I am not a cat person or a dog person
if (('dog' in mypets) and ( 'cat' in mypets) ):
  print ( ('I am a dog person and a cat person') )
elif ( ( 'dog' in mypets ) and ( 'cat' not in mypets) ):
  print ('I am a dog person')
elif ( ('dog' not in mypets) and ('cat' in mypets) ):
  print ('I am a cat person')
elif ( ('dog' not in mypets) and ('cat' not in mypets) ):
  print ('I am not a cat person or a dog person')
# Out:
# I am a dog person and a cat person
